# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.plot(x, values)
plt.xlabel('years'), plt.ylabel('values'), plt.title('value per year')
plt.xticks(x, years)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values)
plt.xlabel('years'), plt.ylabel('values'), plt.title('value per year')
plt.xticks(x, years)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, color = 'dodgerblue') #dodgerblue, C2, #e35f62
plt.xlabel('years'), plt.ylabel('values'), plt.title('value per year')
plt.xticks(x, years)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0, 0.10, 0, 0.10] #Banana랑 Grapes는 10%씩 떼어내라
#plt.pie(ratio)
#plt.pie(ratio, labels = labels, autopct = '%.1f%%')
plt.pie(ratio, labels = labels, autopct = '%.1f%%', startangle=260, 
        counterclock=False, explode = explode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.subplot(221), plt.hist(np.random.randn(100), bins=20, color='k', alpha=0.5)
plt.subplot(222), plt.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30))
plt.subplot(223),plt.plot(np.random.randn(50).cumsum(), 'k--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)

# %%
plt.plot([1.5,3.5,-2,1,6])

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')
# 누적합 cumsum

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50).cumsum(), 'k--') #matplotlib는 가장 최근의 figure와 그 subplot을 그린다.
#_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3) #bin:막대의 갯수, alpha:투명도(0이면 완전 투명, 1이면 완전 불투명)
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.5) #bin:막대의 갯수, alpha:투명도(0이면 완전 투명, 1이면 완전 불투명)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
#sharex, sharey : 모든 subplot들이 같은 x, y축 눈금을 사용한다.
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
        
plt.subplots_adjust(wspace=0.2, hspace=0.2) #그래프간 간격 조정.

# %%
# %matplotlib inline
from numpy.random import randn

plt.plot(randn(30).cumsum(), 'r+--') #k : black, o, --

# %%
plt.close()
plt.plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o') 

# 좀 더 명시적으로 표현 가능, 알아보기 쉽다.

# %%
plt.close()
data = np.random.randn(30).cumsum()

plt.plot(data, 'k--', label='Default')

# %%
# plt.legend
plt.close()
plt.plot(data, 'k--', label='Default')
plt.plot(data,'k-', drawstyle='steps-post', label='steps-post')
# step 계단 모양으로 그려준거임.
plt.legend(loc='best') # 니가 알아서 공간많은곳에 위치하도록

# %% [markdown]
# ### 제목, 축 이름, 눈금 눈금 이름 설정하기

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())

ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                           rotation=30, fontsize='small')
props = {
    'title': 'My first matplotlib plot',
    'xlabel': 'Stages',
    'ylabel': 'Value'
}
ax.set(**props)

# ax.set_xticks로 축 정할수있음.
# ax.set_xticklabels rotation  : 글자 기울려서
# set_을 붙여서 레이블과 제목 달음.
# Out:
# [Text(0.5, 1.0, 'My first matplotlib plot'),
#  Text(0.5, 0, 'Stages'),
#  Text(0, 0.5, 'Value')]

# %%
from numpy.random import randn

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'r--', label='two')
ax.plot(randn(1000).cumsum(), 'b.', label='three')
ax.legend(loc='best') 
#loc는 범례 위치 지정, best : 최대한 방해되지 않는 곳에 두는 옵션

# %%
from datetime import datetime
import pandas as pd

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear stearns fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 70 ),
               xytext = (date, spx.asof(date) + 225),
               arrowprops=dict(facecolor='black', headwidth=4, width=2, headlength=4),
               horizontalalignment='left', verticalalignment='top')
    
# Zoom in on 2007 - 2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')


# annotate 안에 수들을 바꿔서 해보장.
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=1.0)
# 0.2 0.75를 기준으로.

circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=1.0)
# 0.7 0.2를 기준으로 반지름값 0.15이다.

pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                  color='g', alpha=1.0)
# 각 꼭짓점들을 이어준다.

#ax.set_aspect(1)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
# fig랑 ax 객체 안쓰고 그려도 됩니다~~!~!~

# %%
# %matplotlib notebook
import seaborn as sns, numpy as np
sns.set(); np.random.seed(0)
x = np.random.randn(100)
ax=sns.distplot(x, bins=50)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <img src="data:image/png;base64,..." width="432">

# %%
sns.set(style="whitegrid")
import matplotlib.pyplot as plt
import numpy as np
plt.close()
import pandas as pd
import seaborn as sns
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values, bins=100, color='k')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
macro = pd.read_csv('examples/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna() # diff는
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
# 산포도 : regplot

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.regplot('tbilrate', 'unemp', data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1', 'unemp'))
#regplot메소드를 사용해서 산포도와 선형회귀곡선을 함께 그릴수 있다.
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %%
# 오류뜰때

# 산포도 : regplot

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.regplot(x='tbilrate', y='unemp', data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1', 'unemp'))
#regplot메소드를 사용해서 산포도와 선형회귀곡선을 함께 그릴수 있다.
# Out:
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2})
# kde : kernel distribution estimation

# %%
sns.pairplot(trans_data, diag_kind='hist', plot_kws={'alpha': 0.2})

# %%
tips = pd.read_csv('tips.csv')
tips
sns.factorplot(x='day', y='tip_pct', row='time', col='smoker',
              kind = 'bar', data=tips[tips.tip_pct < 1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_352/1021936944.py in <module>
#       2 tips
#       3 sns.factorplot(x='day', y='tip_pct', row='time', col='smoker',
# ----> 4               kind = 'bar', data=tips[tips.tip_pct < 1])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tip_pct'

# %%
# seabon은 matplotlib 상위버전이다.
