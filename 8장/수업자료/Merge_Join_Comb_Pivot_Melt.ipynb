# %% [markdown]
# ### 기준열 이름이 같을 때
# pd.merge(left, right, on = '기준열', how = '조인방식')
# ### 기준열 이름이 다를 때
# pd.merge(left, right, left_on = '왼쪽 열', right_on = '오른쪽 열', how = '조인방식')
#
# left : 왼쪽 데이터프레임
# right : 오른쪽 데이터프레임
# on : (두 데이터프레임의 기준열 이름이 같을 때) 기준열
# how : 조인 방식 {'left', 'right', 'inner', 'outer'} 기본값은 'inner'
# left_on : 기준열 이름이 다를 때, 왼쪽 기준열
# right_on : 기준열 이름이 다를 때, 오른쪽 기준열

# %%
import pandas as pd
fruit = pd.DataFrame({'Num':[123, 456, 789, 1011, 1112],'Fruit':['Apple', 'Banana', 'Cherry', 'Lemon', 'Peach']})
grade  =   pd.DataFrame({'Num':[123, 789, 1314], 'Grade':['A', 'B', 'C']})

# %%
fruit
# Out:
#     Num   Fruit
# 0   123   Apple
# 1   456  Banana
# 2   789  Cherry
# 3  1011   Lemon
# 4  1112   Peach

# %%
grade
# Out:
#     Num Grade
# 0   123     A
# 1   789     B
# 2  1314     C

# %% [markdown]
# ### 1. how = JOIN 방식
# <img src="merge_how.jpg" alt="merge_how" width="500"/>

# %% [markdown]
# #### Left Join
# : 왼쪽 데이터프레임을 기준으로 조인한다. 오른쪽 데이터프레임에 없는 값은 NaN으로 나타난다.

# %%
fruit
# Out:
#     Num   Fruit
# 0   123   Apple
# 1   456  Banana
# 2   789  Cherry
# 3  1011   Lemon
# 4  1112   Peach

# %%
grade
# Out:
#     Num Grade
# 0   123     A
# 1   789     B
# 2  1314     C

# %%
pd.merge(fruit, grade, on = 'Num', how = 'left')
# Out:
#     Num   Fruit Grade
# 0   123   Apple     A
# 1   456  Banana   NaN
# 2   789  Cherry     B
# 3  1011   Lemon   NaN
# 4  1112   Peach   NaN

# %% [markdown]
# #### Right Join
#
# : 오른쪽 데이터프레임을 기준으로 조인한다. 왼쪽 데이터프레임에 없는 값은 NaN으로 나타난다.

# %%
pd.merge(fruit, grade, on = 'Num', how = 'right')
# Out:
#     Num   Fruit Grade
# 0   123   Apple     A
# 1   789  Cherry     B
# 2  1314     NaN     C

# %% [markdown]
# #### Inner Join
#
# : 교집합을 의미한다. 양쪽에 공통으로 있는 값만 나타난다.

# %%
pd.merge(fruit, grade, on = 'Num', how = 'inner')
# Out:
#    Num   Fruit Grade
# 0  123   Apple     A
# 1  789  Cherry     B

# %% [markdown]
# #### Outer Join
#
# : 모든 값이 나타나도록 한다. 왼쪽 데이터프레임과 오른쪽 데이터프레임에 없는 값들은 NaN으로 나타난다.

# %%
pd.merge(fruit, grade, on = 'Num', how = 'outer')
# Out:
#     Num   Fruit Grade
# 0   123   Apple     A
# 1   456  Banana   NaN
# 2   789  Cherry     B
# 3  1011   Lemon   NaN
# 4  1112   Peach   NaN
# 5  1314     NaN     C

# %%
grade.join(fruit, on = 'Num', how='outer')  #컬럼이 겹쳐서 에러가 발생
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-5991c13b52b0> in <module>
# ----> 1 grade.join(fruit, on = 'Num', how='outer')  #컬럼이 겹쳐서 에러가 발생
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
# --> 670         llabels, rlabels = _items_overlap_with_suffix(
#     671             self.left._info_axis, self.right._info_axis, self.suffixes
#     672         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2089
#    2090     if not lsuffix and not rsuffix:
# -> 2091         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2092
#    2093     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['Num'], dtype='object')

# %%
left = pd.DataFrame({'key1':['foo', 'foo', 'bar'],
                    'key2':['one', 'two', 'one'],
                    'lval':[1, 2, 3]})
right = pd.DataFrame({'key1':['foo', 'foo', 'bar', 'bar'],
                     'key2': ['one', 'one', 'one', 'two'],
                     'rval': [4, 5, 6, 7]})

# %%
left
# Out:
#   key1 key2  lval
# 0  foo  one     1
# 1  foo  two     2
# 2  bar  one     3

# %%
right
# Out:
#   key1 key2  rval
# 0  foo  one     4
# 1  foo  one     5
# 2  bar  one     6
# 3  bar  two     7

# %% [markdown]
# ### 2. on = '기준열'
# 공통이 되는 기준 열이 여러 개일 때

# %%
pd.merge(left, right, on = ['key1', 'key2'])
# Out:
#   key1 key2  lval  rval
# 0  foo  one     1     4
# 1  foo  one     1     5
# 2  bar  one     3     6

# %%
pd.merge(left, right, on = ['key1', 'key2'], how='outer')
# Out:
#   key1 key2  lval  rval
# 0  foo  one   1.0   4.0
# 1  foo  one   1.0   5.0
# 2  foo  two   2.0   NaN
# 3  bar  one   3.0   6.0
# 4  bar  two   NaN   7.0

# %% [markdown]
# 공통이 되는 기준 열이 하나일 때

# %%
left
# Out:
#   key1 key2  lval
# 0  foo  one     1
# 1  foo  two     2
# 2  bar  one     3

# %%
right
# Out:
#   key1 key2  rval
# 0  foo  one     4
# 1  foo  one     5
# 2  bar  one     6
# 3  bar  two     7

# %%
pd.merge(left, right, on = 'key1')
# Out:
#   key1 key2_x  lval key2_y  rval
# 0  foo    one     1    one     4
# 1  foo    one     1    one     5
# 2  foo    two     2    one     4
# 3  foo    two     2    one     5
# 4  bar    one     3    one     6
# 5  bar    one     3    two     7

# %%
pd.merge(left, right, on = 'key1', how='inner')
# Out:
#   key1 key2_x  lval key2_y  rval
# 0  foo    one     1    one     4
# 1  foo    one     1    one     5
# 2  foo    two     2    one     4
# 3  foo    two     2    one     5
# 4  bar    one     3    one     6
# 5  bar    one     3    two     7

# %% [markdown]
# 두 데이터프레임의 열 이름이 다를 때
#
# 위 예시처럼 양쪽 데이터프레임에서 merge의 기준이 되는 열의 이름이 같다면 on = '기준열'로 지정해주면 된다. 하지만 양쪽 데이터프레임에서 기준이 되는 열의 이름이 다르다면 각각 left_on = '왼쪽 열', right_on = '오른쪽 열'로 지정하면 된다.

# %%
pd.merge(left, right, left_on = 'key1', right_on='key2', how='outer')
# Out:
#   key1_x key2_x  lval key1_y key2_y  rval
# 0    foo    one   1.0    NaN    NaN   NaN
# 1    foo    two   2.0    NaN    NaN   NaN
# 2    bar    one   3.0    NaN    NaN   NaN
# 3    NaN    NaN   NaN    foo    one   4.0
# 4    NaN    NaN   NaN    foo    one   5.0
# 5    NaN    NaN   NaN    bar    one   6.0
# 6    NaN    NaN   NaN    bar    two   7.0

# %% [markdown]
# #### join과 concat 방법에 대해서도 확인하시오.
# #### 색인으로 병합할때 DataFrame의 join메소드를 사용하면 편리하다.
# #### join메소드는 컬럼이 겹치지 않으며 완전히 같거나 유사한 색인구조를 가진 여러개의 DataFrame 객체를 병합할때 사용할 수있다.

# %% [markdown]
# ## 데이터 합치기
# #### pandas 객체에 저장된 데이터는 여러가지 방법으로 합칠 수 있다.
# ####     1. 'pandas.merge'는 하나 이상의 키를 기준으로 DataFrames의 row를 합친다.
# ####     2. 'pandas.concat'는 하나의 축을 따라 객체를 이어 붙인다.
# ####     3. 'combine_first' 메소드는 두 객체를 포개서 한 객체에서 누락된 데이터를 다른 객체에 있는 값으로 채울수 있게 한다.

# %%
left2 = pd.DataFrame([[1., 2.], [3., 4.], [5., 6.]],
                    index=['a', 'c', 'e'],
                    columns=['Ohio', 'Nevada'])
right2 = pd.DataFrame([[7., 8.], [9., 10.], [11., 12.], [13, 14]],
                     index=['b','c','d','e'],
                     columns=['Missouri','Alabama'])

left2
# Out:
#    Ohio  Nevada
# a   1.0     2.0
# c   3.0     4.0
# e   5.0     6.0

# %%
right2
# Out:
#    Missouri  Alabama
# b       7.0      8.0
# c       9.0     10.0
# d      11.0     12.0
# e      13.0     14.0

# %%
pd.merge(left2, right2, how='outer', left_index=True, right_index=True)
# Out:
#    Ohio  Nevada  Missouri  Alabama
# a   1.0     2.0       NaN      NaN
# b   NaN     NaN       7.0      8.0
# c   3.0     4.0       9.0     10.0
# d   NaN     NaN      11.0     12.0
# e   5.0     6.0      13.0     14.0

# %%
left2.join(right2, how='outer')
# Out:
#    Ohio  Nevada  Missouri  Alabama
# a   1.0     2.0       NaN      NaN
# b   NaN     NaN       7.0      8.0
# c   3.0     4.0       9.0     10.0
# d   NaN     NaN      11.0     12.0
# e   5.0     6.0      13.0     14.0

# %%
s1 = pd.Series([0,1], index=['a', 'b'])
s2 = pd.Series([2,3,4], index=['c', 'd', 'e'])
s3 = pd.Series([5,6], index=['f', 'g'])

# %%
s1
# Out:
# a    0
# b    1
# dtype: int64

# %%
s2
# Out:
# c    2
# d    3
# e    4
# dtype: int64

# %%
s3
# Out:
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1, s2, s3])# 세객체를 묶어서 concat 함수에 전달하면 값과 색인을 연결해준다.
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1, s2, s3], axis=1)#axis=1을 넘기면 결과는 Series가 아니라 DataFrame이 된다.
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
import numpy as np

a = pd.Series([np.nan, 2.5, 0.0, 3.5, 4.5, np.nan],
             index=['f','e','d','c','b','a'])
b = pd.Series([0., np.nan, 2., np.nan, np.nan, 5.],
             index=['a','b','c','d','e','f'])

# %%
a
# Out:
# f    NaN
# e    2.5
# d    0.0
# c    3.5
# b    4.5
# a    NaN
# dtype: float64

# %%
b
# Out:
# a    0.0
# b    NaN
# c    2.0
# d    NaN
# e    NaN
# f    5.0
# dtype: float64

# %%
b.combine_first(a)
# Out:
# a    0.0
# b    4.5
# c    2.0
# d    0.0
# e    2.5
# f    5.0
# dtype: float64

# %%
b.combine_first(a)
# Out:
# a    0.0
# b    4.5
# c    2.0
# d    0.0
# e    2.5
# f    5.0
# dtype: float64

# %% [markdown]
# #### pivot()은 여러 형태로 이루어진 dataframe에 index, columns, values를 각각 지정해주어 melt된 df를 보기 좋은 형태로 재구조화 시켜주는 메서드이다. 즉, unmelt의 개념이다.
# 데이터 테이블 재배치(구조 변경)
#  - 여러 column을 index, values, columns 값으로 사용 가능
#  - Group 연산, 테이블 요약, 그래프 등을 위해 사용
#  - set_index로 계층적 색인 생성 후, unstack 메서드로 형태를 변경하는 과정의 축약형
#
# p1.pivot(index=None, columns=None, values=None)
#       index : index 색인으로 사용될 컬럼
#       columns : column 색인으로 사용될 컬럼
#       values : value에 채우고자 하는 컬럼

# %%
import pandas as pd

df=pd.DataFrame({'store':['Costco','Costco','Costco','Wal-Mart','Wal-Mart','Wal-Mart',"Sam's Club","Sam's Club","Sam's Club"],
               'product':['Potato','Onion','Cucumber','Potato','Onion','Cucumber','Potato','Onion','Cucumber'],
               'price':[3000,1600,2600,3200,1200,2100,2000,2300,3000],
                'quantity':[25,31,57,32,36,21,46,25,9]})
df
# Out:
#         store   product  price  quantity
# 0      Costco    Potato   3000        25
# 1      Costco     Onion   1600        31
# 2      Costco  Cucumber   2600        57
# 3    Wal-Mart    Potato   3200        32
# 4    Wal-Mart     Onion   1200        36
# 5    Wal-Mart  Cucumber   2100        21
# 6  Sam's Club    Potato   2000        46
# 7  Sam's Club     Onion   2300        25
# 8  Sam's Club  Cucumber   3000         9

# %%
df.pivot(index='product', columns='store',values='price')
#df.pivot('product', 'store')['price']
#df.pivot('product', 'store', 'price')
# Out:
# store     Costco  Sam's Club  Wal-Mart
# product
# Cucumber    2600        3000      2100
# Onion       1600        2300      1200
# Potato      3000        2000      3200

# %%
df.pivot(index='product', columns='store',values='quantity')
# Out:
# store     Costco  Sam's Club  Wal-Mart
# product
# Cucumber      57           9        21
# Onion         31          25        36
# Potato        25          46        32

# %%
df.pivot(index='product', columns='store')
# Out:
#           price                     quantity
# store    Costco Sam's Club Wal-Mart   Costco Sam's Club Wal-Mart
# product
# Cucumber   2600       3000     2100       57          9       21
# Onion      1600       2300     1200       31         25       36
# Potato     3000       2000     3200       25         46       32

# %% [markdown]
# ### p1.pivot_table(index, columns, values, aggfunc)
# ###      index : index 색인으로 사용될 컬럼
# ###      columns : column 색인으로 사용될 컬럼
# ###      values : value에 채우고자 하는 컬럼
# ###      aggfund : 데이터 집계함수

# %%
df
# Out:
#         store   product  price  quantity
# 0      Costco    Potato   3000        25
# 1      Costco     Onion   1600        31
# 2      Costco  Cucumber   2600        57
# 3    Wal-Mart    Potato   3200        32
# 4    Wal-Mart     Onion   1200        36
# 5    Wal-Mart  Cucumber   2100        21
# 6  Sam's Club    Potato   2000        46
# 7  Sam's Club     Onion   2300        25
# 8  Sam's Club  Cucumber   3000         9

# %%
df.pivot_table(index='product', columns='store', values='price', aggfunc=sum)
# Out:
# store     Costco  Sam's Club  Wal-Mart
# product
# Cucumber    2600        3000      2100
# Onion       1600        2300      1200
# Potato      3000        2000      3200

# %%
df.pivot_table(index='product', columns='store', aggfunc=sum)
# Out:
#           price                     quantity
# store    Costco Sam's Club Wal-Mart   Costco Sam's Club Wal-Mart
# product
# Cucumber   2600       3000     2100       57          9       21
# Onion      1600       2300     1200       31         25       36
# Potato     3000       2000     3200       25         46       32

# %% [markdown]
# #### melt  :컬럼을 녹여 행으로 보낸다
# pandas.melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index=True)
#
# frame 자리엔 바꿀 df를 넣어주고, id_vars에는 ID 변수를 지정해준다.
# melt는 ID 변수를 기준으로 원래 데이터셋에 있던 컬럼명들을 'variable' 컬럼의 값들로 위에서 아래로 길게 나열하고, 'value' 컬럼에 ID 변수와   variable에 있는 값대로 차례차례 넣어주는 식으로 작동한다.
# value_vars는 'value' 컬럼에 들어가는 값을 지정해준다.

# %%
df
# Out:
#         store   product  price  quantity
# 0      Costco    Potato   3000        25
# 1      Costco     Onion   1600        31
# 2      Costco  Cucumber   2600        57
# 3    Wal-Mart    Potato   3200        32
# 4    Wal-Mart     Onion   1200        36
# 5    Wal-Mart  Cucumber   2100        21
# 6  Sam's Club    Potato   2000        46
# 7  Sam's Club     Onion   2300        25
# 8  Sam's Club  Cucumber   3000         9

# %%
df.melt(id_vars=['product', 'store']) #store와 product를 기준으로 price와 quantity를 녹인다.
#df.melt(['product','store'])
# Out:
#      product       store  variable  value
# 0     Potato      Costco     price   3000
# 1      Onion      Costco     price   1600
# 2   Cucumber      Costco     price   2600
# 3     Potato    Wal-Mart     price   3200
# 4      Onion    Wal-Mart     price   1200
# 5   Cucumber    Wal-Mart     price   2100
# 6     Potato  Sam's Club     price   2000
# 7      Onion  Sam's Club     price   2300
# 8   Cucumber  Sam's Club     price   3000
# 9     Potato      Costco  quantity     25
# 10     Onion      Costco  quantity     31
# 11  Cucumber      Costco  quantity     57
# 12    Potato    Wal-Mart  quantity     32
# 13     Onion    Wal-Mart  quantity     36
# 14  Cucumber    Wal-Mart  quantity     21
# 15    Potato  Sam's Club  quantity     46
# 16     Onion  Sam's Club  quantity     25
# 17  Cucumber  Sam's Club  quantity      9

# %%
df.melt(id_vars=['product','store'],value_vars='quantity')#store와 product를 기준으로 variable은 quantity
#df.melt(['product','store'],'quantity')
# Out:
#     product       store  variable  value
# 0    Potato      Costco  quantity     25
# 1     Onion      Costco  quantity     31
# 2  Cucumber      Costco  quantity     57
# 3    Potato    Wal-Mart  quantity     32
# 4     Onion    Wal-Mart  quantity     36
# 5  Cucumber    Wal-Mart  quantity     21
# 6    Potato  Sam's Club  quantity     46
# 7     Onion  Sam's Club  quantity     25
# 8  Cucumber  Sam's Club  quantity      9

# %%
df.melt(id_vars=['product','store'],var_name='product_info',value_name='product_value') #variable과 value의 이름을 지정가능
# Out:
#      product       store product_info  product_value
# 0     Potato      Costco        price           3000
# 1      Onion      Costco        price           1600
# 2   Cucumber      Costco        price           2600
# 3     Potato    Wal-Mart        price           3200
# 4      Onion    Wal-Mart        price           1200
# 5   Cucumber    Wal-Mart        price           2100
# 6     Potato  Sam's Club        price           2000
# 7      Onion  Sam's Club        price           2300
# 8   Cucumber  Sam's Club        price           3000
# 9     Potato      Costco     quantity             25
# 10     Onion      Costco     quantity             31
# 11  Cucumber      Costco     quantity             57
# 12    Potato    Wal-Mart     quantity             32
# 13     Onion    Wal-Mart     quantity             36
# 14  Cucumber    Wal-Mart     quantity             21
# 15    Potato  Sam's Club     quantity             46
# 16     Onion  Sam's Club     quantity             25
# 17  Cucumber  Sam's Club     quantity              9

# %%
df.melt(id_vars=['product','store'],value_vars='quantity', var_name='product_info',value_name='product_value')
# Out:
#     product       store product_info  product_value
# 0    Potato      Costco     quantity             25
# 1     Onion      Costco     quantity             31
# 2  Cucumber      Costco     quantity             57
# 3    Potato    Wal-Mart     quantity             32
# 4     Onion    Wal-Mart     quantity             36
# 5  Cucumber    Wal-Mart     quantity             21
# 6    Potato  Sam's Club     quantity             46
# 7     Onion  Sam's Club     quantity             25
# 8  Cucumber  Sam's Club     quantity              9

# %%
df1 = df.melt(id_vars=['product','store'],value_vars='quantity')
df1
# Out:
#     product       store  variable  value
# 0    Potato      Costco  quantity     25
# 1     Onion      Costco  quantity     31
# 2  Cucumber      Costco  quantity     57
# 3    Potato    Wal-Mart  quantity     32
# 4     Onion    Wal-Mart  quantity     36
# 5  Cucumber    Wal-Mart  quantity     21
# 6    Potato  Sam's Club  quantity     46
# 7     Onion  Sam's Club  quantity     25
# 8  Cucumber  Sam's Club  quantity      9

# %%
df
# Out:
#         store   product  price  quantity
# 0      Costco    Potato   3000        25
# 1      Costco     Onion   1600        31
# 2      Costco  Cucumber   2600        57
# 3    Wal-Mart    Potato   3200        32
# 4    Wal-Mart     Onion   1200        36
# 5    Wal-Mart  Cucumber   2100        21
# 6  Sam's Club    Potato   2000        46
# 7  Sam's Club     Onion   2300        25
# 8  Sam's Club  Cucumber   3000         9

# %%
df1[df1['store']=='Costco']
# Out:
#     product   store  variable  value
# 0    Potato  Costco  quantity     25
# 1     Onion  Costco  quantity     31
# 2  Cucumber  Costco  quantity     57

# %%
df1[df1['product']=='Potato']
# Out:
#   product       store  variable  value
# 0  Potato      Costco  quantity     25
# 3  Potato    Wal-Mart  quantity     32
# 6  Potato  Sam's Club  quantity     46

# %% [markdown]
# ## 실습
# #### pandas에는 pivot과 pivot_table 두가지를 제공하는데,
# #### 차이는 pivot은 중복된 index와 column을 처리하지 못하는데, pivot_table은 처리할 수 있다. - 즉 Grouping을 할 수 있다.

# %%
data = {'name':['홍길동','홍길동','홍길동','아무개','아무개','아무개'],
        'col_name':['age','sex','address','age','sex','address'],
        'value':[30,'male','seoul',22,'female','busan']}
data_df = pd.DataFrame(data)
data_df
# Out:
#   name col_name   value
# 0  홍길동      age      30
# 1  홍길동      sex    male
# 2  홍길동  address   seoul
# 3  아무개      age      22
# 4  아무개      sex  female
# 5  아무개  address   busan

# %%
data_df.pivot(index='name', columns='col_name', values = 'value')
# Out:
# col_name address age     sex
# name
# 아무개        busan  22  female
# 홍길동        seoul  30    male

# %%
pd.pivot_table(data_df, index='name', columns='col_name', values = 'value', aggfunc='sum')
# Out:
# col_name address age     sex
# name
# 아무개        busan  22  female
# 홍길동        seoul  30    male

# %%
data = {'name':['홍길동','홍길동','홍길동','아무개','아무개','아무개','아무개'],
        'col_name':['age','sex','address','age','sex','address','age'],
        'value':[30,'male','seoul',22,'female','busan',30]}
data_df = pd.DataFrame(data)
data_df
# Out:
#   name col_name   value
# 0  홍길동      age      30
# 1  홍길동      sex    male
# 2  홍길동  address   seoul
# 3  아무개      age      22
# 4  아무개      sex  female
# 5  아무개  address   busan
# 6  아무개      age      30

# %%
data_df.pivot(index='name', columns='col_name', values = 'value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-db2268df6163> in <module>
# ----> 1 data_df.pivot(index='name', columns='col_name', values = 'value')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6672         from pandas.core.reshape.pivot import pivot
#    6673
# -> 6674         return pivot(self, index=index, columns=columns, values=values)
#    6675
#    6676     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     475         else:
#     476             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 477     return indexed.unstack(columns)
#     478
#     479
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3888         from pandas.core.reshape.reshape import unstack
#    3889
# -> 3890         return unstack(self, level, fill_value)
#    3891
#    3892     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     422         if is_extension_array_dtype(obj.dtype):
#     423             return _unstack_extension_series(obj, level, fill_value)
# --> 424         unstacker = _Unstacker(
#     425             obj.index, level=level, constructor=obj._constructor_expanddim,
#     426         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, index, level, constructor)
#     118             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     119
# --> 120         self._make_selectors()
#     121
#     122     @cache_readonly
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     167
#     168         if mask.sum() < len(self.index):
# --> 169             raise ValueError("Index contains duplicate entries, cannot reshape")
#     170
#     171         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
import numpy as np
pd.pivot_table(data_df, index='name', columns='col_name', values = 'value', aggfunc='max')
# Out:
# col_name address age     sex
# name
# 아무개        busan  30  female
# 홍길동        seoul  30    male

# %%
#seaborn에서 제공하는 데이터 사용
import seaborn as sns
dia = sns.load_dataset('diamonds')
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### 1. 다이아몬드의 cut과 color의 상태에 따른 가격(price)의 평균을 구하시오

# %%
dia.pivot(index='cut', columns='color', values='price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-359aceb1bfd1> in <module>
# ----> 1 dia.pivot(index='cut', columns='color', values='price')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6672         from pandas.core.reshape.pivot import pivot
#    6673
# -> 6674         return pivot(self, index=index, columns=columns, values=values)
#    6675
#    6676     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     475         else:
#     476             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 477     return indexed.unstack(columns)
#     478
#     479
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3888         from pandas.core.reshape.reshape import unstack
#    3889
# -> 3890         return unstack(self, level, fill_value)
#    3891
#    3892     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     422         if is_extension_array_dtype(obj.dtype):
#     423             return _unstack_extension_series(obj, level, fill_value)
# --> 424         unstacker = _Unstacker(
#     425             obj.index, level=level, constructor=obj._constructor_expanddim,
#     426         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, index, level, constructor)
#     118             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     119
# --> 120         self._make_selectors()
#     121
#     122     @cache_readonly
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     167
#     168         if mask.sum() < len(self.index):
# --> 169             raise ValueError("Index contains duplicate entries, cannot reshape")
#     170
#     171         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
dia.pivot_table(index='cut', columns='color', values='price', aggfunc='mean')
# Out:
# color                D            E            F            G            H  \
# cut
# Ideal      2629.094566  2597.550090  3374.939362  3720.706388  3889.334831
# Premium    3631.292576  3538.914420  4324.890176  4500.742134  5216.706780
# Very Good  3470.467284  3214.652083  3778.820240  3872.753806  4535.390351
# Good       3405.382175  3423.644159  3495.750275  4123.482204  4276.254986
# Fair       4291.061350  3682.312500  3827.003205  4239.254777  5135.683168
#
# color                I            J
# cut
# Ideal      4451.970377  4918.186384
# Premium    5946.180672  6294.591584
# Very Good  5255.879568  5103.513274
# Good       5078.532567  4574.172638
# Fair       4685.445714  4975.655462

# %% [markdown]
# ### 2. 다이아몬드의 cut과 color를 행인덱스, clarity를 열인덱스로 하여 중위가격을 구하시오

# %%
dia.pivot_table(index=['cut', 'color'], columns='clarity', values='price', aggfunc=np.median)
# Out:
# clarity               IF    VVS1    VVS2     VS1     VS2     SI1     SI2  \
# cut       color
# Ideal     D       4184.5  1547.0  1295.0  1330.0  1113.5  1610.5  2533.5
#           E       1207.0  1057.0  1106.0  1097.0  1576.0  1749.0  3429.0
#           F        979.0  1124.0  2059.0  1911.5  1625.0  2596.0  3246.0
#           G       1014.0  1114.0  1918.0  1876.0  2383.0  2397.0  3903.5
#           H       1055.0  1029.5   880.0  1665.0  2446.5  4587.0  4536.0
#           I        865.0   974.0  1316.0  2557.0  2832.0  4457.5  5237.5
#           J        828.0   994.0  2143.0  3267.0  4280.5  4443.0  4684.5
# Premium   D      10129.0  1582.0  1323.0  2860.0  1775.0  1786.0  4007.0
#           E       1207.0  1044.0  1082.0  1748.5  1694.0  2287.5  3846.0
#           F       1085.0  1356.0  2160.0  2830.5  1869.0  2812.5  4043.0
#           G       1148.0  1155.0  1914.0  1815.0  2770.0  3669.0  4273.5
#           H       1097.0   907.0   880.0  2365.5  5212.5  4836.0  4872.0
#           I       1056.0  1033.0  1035.0  3763.0  5832.0  4872.0  5216.5
#           J       5844.0  7284.5  6862.0  5304.0  5000.5  4536.0  5310.0
# Very Good D       9182.0  1158.0  1010.0  1882.0  1786.0  2517.0  3965.0
#           E       1421.0   674.5   730.5  1852.0  1786.0  2517.5  3674.0
#           F       1284.0   932.5  1131.0  2406.0  2488.0  2633.0  3770.0
#           G       1271.0  1013.0  1835.5  1770.0  2994.0  2332.0  3891.0
#           H       1187.0   967.0   839.0  2594.0  4145.5  4484.0  4483.0
#           I       2057.0  1164.0  2106.0  3656.0  3993.0  4249.0  4957.5
#           J        828.0  2093.0  5665.0  3361.5  4219.0  4145.0  4341.0
# Good      D      15081.0  1159.0  1080.0  2816.0  2768.5  2318.0  3540.0
#           E        912.0   826.0  1523.5  2826.0  2661.5  2305.0  3185.5
#           F       1806.0   965.0  2238.0  1779.5  2631.0  2409.0  3886.0
#           G       1706.5  1235.0  1800.0  3202.0  3947.0  3615.0  3852.0
#           H       4553.5   893.0  1821.0  2421.0  3569.5  3726.0  3965.0
#           I        915.5  1737.0  2309.0  3447.0  4138.0  3382.0  4953.0
#           J       1557.0  4633.0  3193.0  1989.5  3839.5  3672.0  4559.0
# Fair      D       1440.0  1792.0  1980.0  2747.0  4107.0  3900.0  3473.0
#           E          NaN  2805.0  2079.0  2071.0  2508.0  3508.0  3437.5
#           F       2502.5  1040.0  2286.0  3002.0  2762.0  3197.0  3540.0
#           G       1488.0  2797.0  2167.0  2396.0  4838.0  3145.0  3598.5
#           H          NaN  4115.0  2717.0  3800.0  3658.0  3816.0  4129.0
#           I          NaN  4194.0  2321.5  2732.0  2793.5  3308.5  4704.0
#           J          NaN  1691.0  2998.0  3022.0  2854.0  3603.5  3302.0
#
# clarity              I1
# cut       color
# Ideal     D      3886.0
#           E      3552.0
#           F      3544.0
#           G      3909.5
#           H      3951.0
#           I      3328.0
#           J      9454.0
# Premium   D      3740.0
#           E      3343.5
#           F      2999.5
#           G      3045.0
#           H      3202.0
#           I      3636.5
#           J      2825.0
# Very Good D      2618.0
#           E      3256.0
#           F      3774.0
#           G      3014.0
#           H      4256.0
#           I      3789.5
#           J      3770.0
# Good      D      4013.5
#           E      3484.0
#           F      2098.0
#           G      3127.0
#           H      3156.5
#           I      3098.0
#           J      3356.0
# Fair      D      5538.5
#           E      2036.0
#           F      1570.0
#           G      1954.0
#           H      3339.5
#           I      2396.0
#           J      5405.0

# %% [markdown]
# ### 2. 다이아몬드의 cut과 color에 따른 가격(price)는 중위가격, 무게(carat)은 합계로 따로 집계하시오.

# %%
dia.pivot_table(index='cut', columns='color', values=['price', 'carat'], aggfunc= { 'price': 'median','carat': 'sum'} )
# Out:
#              carat                                                        \
# color            D        E        F        G        H        I        J
# cut
# Ideal      1603.38  2257.50  2509.20  3422.29  2490.52  1910.97   952.98
# Premium    1156.64  1677.37  1927.82  2460.51  2398.82  1634.97  1044.82
# Very Good  1053.69  1623.16  1603.44  1762.87  1670.69  1260.53   768.32
# Good        492.87   695.21   705.32   741.13   642.14   551.87   337.56
# Fair        149.98   191.88   282.27   321.48   369.41   209.66   159.60
#
#             price
# color           D       E       F       G       H       I       J
# cut
# Ideal      1576.0  1437.0  1775.0  1857.5  2278.0  2659.0  4096.0
# Premium    2009.0  1928.0  2841.0  2745.0  4511.0  4640.0  5063.0
# Very Good  2310.0  1989.5  2471.0  2437.0  3734.0  3888.0  4113.0
# Good       2728.5  2420.0  2647.0  3340.0  3468.5  3639.5  3733.0
# Fair       3730.0  2956.0  3035.0  3057.0  3816.0  3246.0  3302.0
