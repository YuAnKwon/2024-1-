# %%
# kto_201901.xlsx 엑셀 데이터 불러오기
import pandas as pd 
kto_201901 = pd.read_excel('./files/kto_201901.xlsx', 
                          header=1,         #컬럼이름은 두번빼 줄에 위치
                          usecols='A:G',    #컬럼은 A부터 G까지
                          skipfooter=4)     #마지막 4개의 row는 불러오지 않는다.
kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계
# 0      아시아주  765082  10837  1423  14087  125521  916950
# 1        일본  198805   2233   127    785    4576  206526
# 2        대만   86393     74    22    180    1285   87954
# 3        홍콩   34653     59     2     90    1092   35896
# 4       마카오    2506      2     0     17      45    2570
# ..      ...     ...    ...   ...    ...     ...     ...
# 62  아프리카 기타     768    718    90    206     908    2690
# 63     기타대륙      33      4     0      1      16      54
# 64     국적미상      33      4     0      1      16      54
# 65     교포소계       0      0     0      0   15526   15526
# 66       교포       0      0     0      0   15526   15526
#
# [67 rows x 7 columns]

# %%
kto_201901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
kto_201901.describe()
# Out:
#                  관광            상용           공용         유학/연수             기타  \
# count      67.00000     67.000000    67.000000     67.000000      67.000000
# mean    26396.80597    408.208955   132.507463    477.462687    5564.208955
# std    102954.04969   1416.040302   474.406339   2009.484800   17209.438418
# min         0.00000      0.000000     0.000000      0.000000      16.000000
# 25%       505.00000     14.500000     2.500000     17.500000     260.000000
# 50%      1304.00000     45.000000    14.000000     43.000000     912.000000
# 75%      8365.00000    176.500000    38.000000    182.000000    2824.500000
# max    765082.00000  10837.000000  2657.000000  14087.000000  125521.000000
#
#                    계
# count      67.000000
# mean    32979.194030
# std    122821.369969
# min        54.000000
# 25%       927.000000
# 50%      2695.000000
# 75%     14905.500000
# max    916950.000000

# %%
# 숫자 0이 포함되어 있는거 출력

kto_201901[ (kto_201901['관광']==0)| (kto_201901['상용']==0)| (kto_201901['공용']==0)|(kto_201901['유학/연수']==0)]
# Out:
#         국적    관광   상용  공용  유학/연수     기타      계
# 4      마카오  2506    2   0     17     45   2570
# 20    이스라엘   727   12   0      9     57    805
# 22  우즈베키스탄  1958  561   0    407   2828   5754
# 38     스위스   613   18   0     19     97    747
# 45     그리스   481   17   4      0    273    775
# 46    포르투갈   416   14   0     13    121    564
# 51   크로아티아   226   12   0      3    250    491
# 54     폴란드   713   10   0     27    574   1324
# 59  대양주 기타   555    3   4      0     52    614
# 63    기타대륙    33    4   0      1     16     54
# 64    국적미상    33    4   0      1     16     54
# 65    교포소계     0    0   0      0  15526  15526
# 66      교포     0    0   0      0  15526  15526

# %%
kto_201901['기준년월'] = '2019-01'
kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계     기준년월
# 0      아시아주  765082  10837  1423  14087  125521  916950  2019-01
# 1        일본  198805   2233   127    785    4576  206526  2019-01
# 2        대만   86393     74    22    180    1285   87954  2019-01
# 3        홍콩   34653     59     2     90    1092   35896  2019-01
# 4       마카오    2506      2     0     17      45    2570  2019-01
# ..      ...     ...    ...   ...    ...     ...     ...      ...
# 62  아프리카 기타     768    718    90    206     908    2690  2019-01
# 63     기타대륙      33      4     0      1      16      54  2019-01
# 64     국적미상      33      4     0      1      16      54  2019-01
# 65     교포소계       0      0     0      0   15526   15526  2019-01
# 66       교포       0      0     0      0   15526   15526  2019-01
#
# [67 rows x 8 columns]

# %%
# 나라 몇개 있는지 체크

print(kto_201901['국적'].unique())
print('나라 개수 : ',len(kto_201901['국적'].unique()))
# Out:
# ['아시아주' '일본' '대만' '홍콩' '마카오' '태국' '말레이시아' '필리핀' '인도네시아' '싱가포르' '미얀마' '베트남'
#  '인도' '스리랑카' '파키스탄' '방글라데시' '캄보디아' '몽골' '중국' '이란' '이스라엘' '터키' '우즈베키스탄'
#  '카자흐스탄' 'GCC' '아시아 기타' '미주' '미국' '캐나다' '멕시코' '브라질' '미주 기타' '구주' '영국' '독일'
#  '프랑스' '네덜란드' '스웨덴' '스위스' '이탈리아' '덴마크' '노르웨이' '벨기에' '오스트리아' '스페인' '그리스'
#  '포르투갈' '핀란드' '아일랜드' '우크라이나' '러시아' '크로아티아' '루마니아' '불가리아' '폴란드' '구주 기타'
#  '대양주' '오스트레일리아' '뉴질랜드' '대양주 기타' '아프리카주' '남아프리카공화국' '아프리카 기타' '기타대륙'
#  '국적미상' '교포소계' '교포']
# 나라 개수 :  67

# %%
# 대륙명은 제거해야함. 

continents_list = ['아시아주','미주','구주','대양주','아프리카주','기타대륙', '교포소계']

# 대륙명 리스트에 있는 애들 없애기
# 1. 국적을 index로만들고 drop하기

kto_1=kto_201901.set_index('국적')
kto_1.drop(continents_list).reset_index()[:10] # drop하고 다시 인덱스 되돌리기
# Out:
#       국적      관광    상용   공용  유학/연수     기타       계     기준년월
# 0     일본  198805  2233  127    785   4576  206526  2019-01
# 1     대만   86393    74   22    180   1285   87954  2019-01
# 2     홍콩   34653    59    2     90   1092   35896  2019-01
# 3    마카오    2506     2    0     17     45    2570  2019-01
# 4     태국   34004    37  199     96   6998   41334  2019-01
# 5  말레이시아   19043    95    7     99   2821   22065  2019-01
# 6    필리핀   14279   211  161    184  15638   30473  2019-01
# 7  인도네시아   14183   136   38    187   4298   18842  2019-01
# 8   싱가포르    8372    94    8     48   1333    9855  2019-01
# 9    미얀마    1304    10   31     67   3877    5289  2019-01

# %%
# 2. isin 메서드 쓰기
filtered_df = kto_201901[~kto_201901['국적'].isin(continents_list)]
filtered_df[:10]
# Out:
#        국적      관광    상용   공용  유학/연수     기타       계     기준년월
# 1      일본  198805  2233  127    785   4576  206526  2019-01
# 2      대만   86393    74   22    180   1285   87954  2019-01
# 3      홍콩   34653    59    2     90   1092   35896  2019-01
# 4     마카오    2506     2    0     17     45    2570  2019-01
# 5      태국   34004    37  199     96   6998   41334  2019-01
# 6   말레이시아   19043    95    7     99   2821   22065  2019-01
# 7     필리핀   14279   211  161    184  15638   30473  2019-01
# 8   인도네시아   14183   136   38    187   4298   18842  2019-01
# 9    싱가포르    8372    94    8     48   1333    9855  2019-01
# 10    미얀마    1304    10   31     67   3877    5289  2019-01

# %%
# 대륙컬럼 만들기
# 대륙 컬럼 생성을 위한 목록 만들어 놓기 
continents = ['아시아']*25 + ['아메리카']*5 + ['유럽']*23 + ['오세아니아']*3 + ['아프리카']*2 + ['기타대륙'] + ['교포']    
print(continents)
# Out:
# ['아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아시아', '아메리카', '아메리카', '아메리카', '아메리카', '아메리카', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '유럽', '오세아니아', '오세아니아', '오세아니아', '아프리카', '아프리카', '기타대륙', '교포']

# %%
# 대륙컬럼 추가

filtered_df['대륙'] = continents
filtered_df
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_17928\959550883.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['대륙'] = continents
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙
# 1         일본  198805  2233   127    785   4576  206526  2019-01    아시아
# 2         대만   86393    74    22    180   1285   87954  2019-01    아시아
# 3         홍콩   34653    59     2     90   1092   35896  2019-01    아시아
# 4        마카오    2506     2     0     17     45    2570  2019-01    아시아
# 5         태국   34004    37   199     96   6998   41334  2019-01    아시아
# 6      말레이시아   19043    95     7     99   2821   22065  2019-01    아시아
# 7        필리핀   14279   211   161    184  15638   30473  2019-01    아시아
# ...

# %%
# 관광객 비율(%) 컬럼 만들기

filtered_df['관광객비율(%)'] = round(filtered_df['관광']/filtered_df['계'] *100,1)
filtered_df
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_17928\391121704.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['관광객비율(%)'] = round(filtered_df['관광']/filtered_df['계'] *100,1)
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 1         일본  198805  2233   127    785   4576  206526  2019-01    아시아
# 2         대만   86393    74    22    180   1285   87954  2019-01    아시아
# 3         홍콩   34653    59     2     90   1092   35896  2019-01    아시아
# 4        마카오    2506     2     0     17     45    2570  2019-01    아시아
# 5         태국   34004    37   199     96   6998   41334  2019-01    아시아
# 6      말레이시아   19043    95     7     99   2821   22065  2019-01    아시아
# ...

# %%
# 관광객 비율이 가장 낮은 나라 출력
filtered_df.sort_values(by='관광객비율(%)').head(1)
# Out:
#     국적  관광  상용  공용  유학/연수     기타      계     기준년월  대륙  관광객비율(%)
# 66  교포   0   0   0      0  15526  15526  2019-01  교포       0.0

# %%
# 각 대륙들의 평균 관광객 비율을 구하라.

# pivot table이랑 groupby로 만드시오.

grouped = filtered_df.groupby('대륙')
grouped[['관광객비율(%)']].mean()
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   61.100000
# 아메리카   68.200000
# 아시아    59.624000
# 아프리카   32.700000
# 오세아니아  84.833333
# 유럽     63.826087

# %%
filtered_df.pivot_table(index='대륙',values='관광객비율(%)',aggfunc='mean')
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   61.100000
# 아메리카   68.200000
# 아시아    59.624000
# 아프리카   32.700000
# 오세아니아  84.833333
# 유럽     63.826087

# %%
# 총 관광객 수

total_tourist = filtered_df['관광'].sum()
total_tourist
# Out:
# 884293

# %%
# 전체 나라중에서 관광객 비율 만들기
# 전체에서 각 나라의 관광객이 몇퍼센트를 가지고있는가.
filtered_df['전체비율(%)'] = round(filtered_df['관광'] / total_tourist*100,1)
filtered_df
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_17928\3155836816.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['전체비율(%)'] = round(filtered_df['관광'] / total_tourist*100,1)
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 1         일본  198805  2233   127    785   4576  206526  2019-01    아시아
# 2         대만   86393    74    22    180   1285   87954  2019-01    아시아
# 3         홍콩   34653    59     2     90   1092   35896  2019-01    아시아
# 4        마카오    2506     2     0     17     45    2570  2019-01    아시아
# 5         태국   34004    37   199     96   6998   41334  2019-01    아시아
# 6      말레이시아   19043    95     7     99   2821   22065  2019-01    아시아
# ...

# %%
# 전체비율 높은 순으로 

filtered_df.sort_values(by='전체비율(%)',ascending=False).head(10)
# Out:
#        국적      관광    상용    공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)  \
# 18     중국  320113  2993   138   8793  60777  392814  2019-01   아시아      81.5
# 1      일본  198805  2233   127    785   4576  206526  2019-01   아시아      96.3
# 2      대만   86393    74    22    180   1285   87954  2019-01   아시아      98.2
# 27     미국   42989   418  2578    229  16523   62737  2019-01  아메리카      68.5
# 3      홍콩   34653    59     2     90   1092   35896  2019-01   아시아      96.5
# 5      태국   34004    37   199     96   6998   41334  2019-01   아시아      82.3
# 6   말레이시아   19043    95     7     99   2821   22065  2019-01   아시아      86.3
# 50    러시아   17260   181    37    191   7525   25194  2019-01    유럽      68.5
# 7     필리핀   14279   211   161    184  15638   30473  2019-01   아시아      46.9
# 8   인도네시아   14183   136    38    187   4298   18842  2019-01   아시아      75.3
#
#     전체비율(%)
# 18     36.2
# 1      22.5
# 2       9.8
# 27      4.9
# 3       3.9
# 5       3.8
# 6       2.2
# 50      2.0
# ...

# %%
# create_kto_data 함수 생성하기 
def create_kto_data(yy, mm):  
    #1. 불러올 Excel 파일 경로를 지정해주기
    file_path = './files/kto_{}{}.xlsx'.format(yy, mm)  
    
    # 2. Excel 파일 불러오기 
    df = pd.read_excel(file_path, header=1, skipfooter=4, usecols='A:G')
    
    # 3. "기준년월" 컬럼 추가하기 
    df['기준년월'] = '{}-{}'.format(yy, mm) 
    
    # 4. "국적" 컬럼에서 대륙 제거하고 국가만 남기기 
    ignore_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']    # 제거할 대륙명 선정하기 
    condition = (df['국적'].isin(ignore_list) == False)    # 대륙 미포함 조건 
    df_country = df[condition].reset_index(drop=True) 
    
    # 5. "대륙" 컬럼 추가하기 
    continents = ['아시아']*25 + ['아메리카']*5 + ['유럽']*23 + ['대양주']*3 + ['아프리카']*2 + ['기타대륙'] + ['교포']    # 대륙 컬럼 생성을 위한 목록 만들어 놓기 
    df_country['대륙'] = continents   
                       
    # 6. 국가별 "관광객비율(%)" 컬럼 추가하기 
    df_country['관광객비율(%)'] = round(df_country.관광 / df_country.계 * 100, 1) 
                       
    # 7. "전체비율(%)" 컬럼 추가하기 
    tourist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = round(df_country['관광'] / tourist_sum * 100, 1)
    
    # 8. 결과 출력하기 
    return(df_country)

# %%
# create_kto_data() 함수를 활용해서 2018년 12월 데이터 불러오기  
kto_test= create_kto_data(2018,12)
kto_test.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  252461  1698  161    608  3593  258521  2018-12  아시아      97.7
# 1   대만   85697    71   22    266  1252   87308  2018-12  아시아      98.2
# 2   홍콩   58355    41    3    208   939   59546  2018-12  아시아      98.0
# 3  마카오    6766     0    1     20    36    6823  2018-12  아시아      99.2
# 4   태국   47242    42  302     58  6382   54026  2018-12  아시아      87.4
#
#    전체비율(%)
# 0     22.7
# 1      7.7
# 2      5.2
# 3      0.6
# 4      4.2

# %%
# 기준년월 출력하기  (20101~201912)

for year in range(2010,2020):
    for month in range(1,13):
        yymm = '{}{}'.format(year,month)
        print(yymm)
# Out:
# 20101
# 20102
# 20103
# 20104
# 20105
# 20106
# 20107
# 20108
# 20109
# 201010
# 201011
# 201012
# 20111
# 20112
# 20113
# 20114
# 20115
# 20116
# 20117
# 20118
# 20119
# 201110
# 201111
# 201112
# 20121
# 20122
# 20123
# 20124
# 20125
# 20126
# 20127
# 20128
# 20129
# 201210
# 201211
# 201212
# 20131
# 20132
# 20133
# 20134
# 20135
# 20136
# 20137
# 20138
# 20139
# 201310
# 201311
# 201312
# 20141
# 20142
# 20143
# 20144
# 20145
# 20146
# 20147
# 20148
# 20149
# 201410
# 201411
# 201412
# 20151
# 20152
# 20153
# 20154
# 20155
# 20156
# 20157
# 20158
# 20159
# 201510
# 201511
# 201512
# 20161
# 20162
# 20163
# 20164
# 20165
# 20166
# 20167
# 20168
# 20169
# 201610
# 201611
# 201612
# 20171
# 20172
# 20173
# 20174
# 20175
# 20176
# 20177
# 20178
# 20179
# 201710
# 201711
# 201712
# 20181
# 20182
# 20183
# 20184
# 20185
# 20186
# 20187
# 20188
# 20189
# 201810
# 201811
# 201812
# 20191
# 20192
# 20193
# 20194
# 20195
# 20196
# 20197
# 20198
# 20199
# 201910
# 201911
# 201912

# %%
# 201001 ~ 201912 까지  6자리로 출력하기  - zfill 사용
for yy in range(2010, 2020):
    for mm in range(1, 13):
        mm_str = str(mm).zfill(2)
        yymm = '{}{}'.format(yy, mm_str)
        print(yymm)
# Out:
# 201001
# 201002
# 201003
# 201004
# 201005
# 201006
# 201007
# 201008
# 201009
# 201010
# 201011
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# ...

# %%
# 201001 ~ 201912 까지  6자리로 출력하기  - 문자열 formatting 사용
for yy in range(2010, 2020):
    for mm in range(1, 13):
        yymm = '{}{:02d}'.format(yy, mm)
        print(yymm)
# Out:
# 201001
# 201002
# 201003
# 201004
# 201005
# 201006
# 201007
# 201008
# 201009
# 201010
# 201011
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# ...

# %%
df = pd.DataFrame()
for yy in range(2010, 2019):
    for mm in range(1, 13):
        yymm = '{}{:02d}'.format(yy, mm)
        df= pd.concat([df,create_kto_data(yy,'{:02d}'.format(mm))],ignore_index=True)
        
for yy in range(2019,2020):
    for mm in range(1, 9):
        yymm = '{}{:02d}'.format(yy, mm)
        df= pd.concat([df,create_kto_data(yy,'{:02d}'.format(mm))],ignore_index=True)
df
# Out:
#             국적      관광    상용   공용  유학/연수     기타       계     기준년월    대륙  \
# 0           일본  202825  1750   89    549   3971  209184  2010-01   아시아
# 1           대만   35788    41   17     37    516   36399  2010-01   아시아
# 2           홍콩   13874    55    0     21    595   14545  2010-01   아시아
# 3          마카오     554     0    0      0      0     554  2010-01   아시아
# 4           태국   13374    39   13     53   4335   17814  2010-01   아시아
# ...        ...     ...   ...  ...    ...    ...     ...      ...   ...
# 6955    대양주 기타     519     1    6      9     74     609  2019-08   대양주
# 6956  남아프리카공화국     634     6    1     11   1235    1887  2019-08  아프리카
# 6957   아프리카 기타    2081   593  165    841   1184    4864  2019-08  아프리카
# 6958      국적미상      36     1    0      8     12      57  2019-08  기타대륙
# 6959        교포       0     0    0      0  16560   16560  2019-08    교포
#
#       관광객비율(%)  전체비율(%)
# 0         97.0     50.6
# 1         98.3      8.9
# 2         95.4      3.5
# ...

# %%
# 통합 데이터 생성하기  - 2019가 9월 이후로 없어서요.
df = pd.DataFrame()

# 패턴 분석결과를 이중 반복문을 통해 구현 
for yy in range(2010, 2020):
    for mm in range(1, 13):
        # try 이하 구문을 실행 
        try:
            # 앞서 만든 create_kto_data 함수로 Excel 데이터를 temp 에 불러오기 
            temp = create_kto_data(str(yy), str(mm).zfill(2))

            # temp 로 불러온 데이터를 df 밑으로 추가하기 
            df = pd.concat([df,temp], ignore_index=True)
        # 만약 try 구문에서 에러가 발생하면 except 이후를 실행 
        except:
            pass
df
# Out:
#             국적      관광    상용   공용  유학/연수     기타       계     기준년월    대륙  \
# 0           일본  202825  1750   89    549   3971  209184  2010-01   아시아
# 1           대만   35788    41   17     37    516   36399  2010-01   아시아
# 2           홍콩   13874    55    0     21    595   14545  2010-01   아시아
# 3          마카오     554     0    0      0      0     554  2010-01   아시아
# 4           태국   13374    39   13     53   4335   17814  2010-01   아시아
# ...        ...     ...   ...  ...    ...    ...     ...      ...   ...
# 6955    대양주 기타     519     1    6      9     74     609  2019-08   대양주
# 6956  남아프리카공화국     634     6    1     11   1235    1887  2019-08  아프리카
# 6957   아프리카 기타    2081   593  165    841   1184    4864  2019-08  아프리카
# 6958      국적미상      36     1    0      8     12      57  2019-08  기타대륙
# 6959        교포       0     0    0      0  16560   16560  2019-08    교포
#
#       관광객비율(%)  전체비율(%)
# 0         97.0     50.6
# 1         98.3      8.9
# 2         95.4      3.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6960 entries, 0 to 6959
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국적        6960 non-null   object
#  1   관광        6960 non-null   int64
#  2   상용        6960 non-null   int64
#  3   공용        6960 non-null   int64
#  4   유학/연수     6960 non-null   int64
#  5   기타        6960 non-null   int64
#  6   계         6960 non-null   int64
#  7   기준년월      6960 non-null   object
#  8   대륙        6960 non-null   object
#  9   관광객비율(%)  6960 non-null   float64
#  10  전체비율(%)   6960 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 598.2+ KB

# %%
# df 데이터 엑셀로 저장하기
df.to_excel('./files/kto_total.xlsx', index = False)

# %%
# 각 년도 별로 합치는것도 해봥
for year in range(2010,2020):
    df.loc[df['기준년월'].str.contains(str(year)), 'year'] = str(year)
df
# Out:
#             국적      관광    상용   공용  유학/연수     기타       계     기준년월    대륙  \
# 0           일본  202825  1750   89    549   3971  209184  2010-01   아시아
# 1           대만   35788    41   17     37    516   36399  2010-01   아시아
# 2           홍콩   13874    55    0     21    595   14545  2010-01   아시아
# 3          마카오     554     0    0      0      0     554  2010-01   아시아
# 4           태국   13374    39   13     53   4335   17814  2010-01   아시아
# ...        ...     ...   ...  ...    ...    ...     ...      ...   ...
# 6955    대양주 기타     519     1    6      9     74     609  2019-08   대양주
# 6956  남아프리카공화국     634     6    1     11   1235    1887  2019-08  아프리카
# 6957   아프리카 기타    2081   593  165    841   1184    4864  2019-08  아프리카
# 6958      국적미상      36     1    0      8     12      57  2019-08  기타대륙
# 6959        교포       0     0    0      0  16560   16560  2019-08    교포
#
#       관광객비율(%)  전체비율(%)  year
# 0         97.0     50.6  2010
# 1         98.3      8.9  2010
# ...

# %%
df['year'] = df['기준년월'].str.split('-').str[0]

#이것도됨

# %%
# 년도별로 한거.
df_pivot_table = df.pivot_table(index=['year','국적'],aggfunc='mean')
df_pivot_table
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_17928\616404499.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df_pivot_table = df.pivot_table(index=['year','국적'],aggfunc='mean')
#                        계          공용            관광   관광객비율(%)            기타  \
# year 국적
# 2010 GCC      705.916667    8.666667    504.083333  69.400000     60.166667
#      교포     26624.500000    0.000000      0.000000   0.000000  26624.500000
#      구주 기타   1924.833333    2.916667   1230.250000  63.808333    608.833333
#      국적미상      16.000000    0.000000     13.583333  83.133333      1.250000
#      그리스      664.583333    0.333333    370.833333  55.641667    263.750000
# ...                  ...         ...           ...        ...           ...
# 2019 폴란드     1948.875000    1.875000   1260.000000  63.275000    639.125000
# ...

# %%
grouped = df.groupby(['year','국적'])
grouped.agg('mean') # numeric_only=True
# Out:
#                       관광          상용          공용       유학/연수            기타  \
# year 국적
# 2010 GCC      504.083333  112.416667    8.666667   20.583333     60.166667
#      교포         0.000000    0.000000    0.000000    0.000000  26624.500000
#      구주 기타   1230.250000   43.583333    2.916667   39.250000    608.833333
#      국적미상      13.583333    1.083333    0.000000    0.083333      1.250000
#      그리스      370.833333   29.250000    0.333333    0.416667    263.750000
# ...                  ...         ...         ...         ...           ...
# 2019 폴란드     1260.000000   10.625000    1.875000   37.250000    639.125000
#      프랑스     7168.750000  247.375000   47.500000  502.375000   1176.875000
#      핀란드      660.375000   12.250000    2.125000   56.375000    381.875000
#      필리핀    21717.250000  181.875000  146.750000  136.000000  18718.250000
#      홍콩     55336.125000   55.875000    2.875000  255.875000    990.250000
#
#                        계   관광객비율(%)   전체비율(%)
# year 국적
# ...

# %%
grouped = df.groupby(['year','대륙'])
grouped.agg('mean',numeric_only=True) # numeric_only=True
# Out:
#                      관광          상용          공용        유학/연수            기타  \
# year 대륙
# 2010 교포        0.000000    0.000000    0.000000     0.000000  26624.500000
#      기타대륙     13.583333    1.083333    0.000000     0.083333      1.250000
#      대양주    3271.472222  166.388889   17.083333     5.750000    597.333333
#      아메리카   9753.650000  254.950000  350.383333    46.316667   3159.033333
#      아시아   17494.083333  746.686667   27.576667   427.073333   4099.626667
# ...                 ...         ...         ...          ...           ...
# 2019 대양주    4883.750000   34.750000   19.458333    21.458333    661.166667
#      아메리카  16924.225000   95.600000  614.425000   165.875000   4414.625000
#      아시아   40116.385000  481.430000   96.530000  1252.685000   5835.040000
#      아프리카   1052.375000  358.875000   45.562500   146.000000    840.937500
#      유럽     2901.347826   52.668478    9.983696    80.760870    850.385870
#
#                       계   관광객비율(%)   전체비율(%)
# year 대륙
# ...

# %%
# 전체 데이터 읽어 오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('./files/kto_total.xlsx')
df
# Out:
#             국적      관광    상용   공용  유학/연수     기타       계     기준년월    대륙  \
# 0           일본  202825  1750   89    549   3971  209184  2010-01   아시아
# 1           대만   35788    41   17     37    516   36399  2010-01   아시아
# 2           홍콩   13874    55    0     21    595   14545  2010-01   아시아
# 3          마카오     554     0    0      0      0     554  2010-01   아시아
# 4           태국   13374    39   13     53   4335   17814  2010-01   아시아
# ...        ...     ...   ...  ...    ...    ...     ...      ...   ...
# 6955    대양주 기타     519     1    6      9     74     609  2019-08   대양주
# 6956  남아프리카공화국     634     6    1     11   1235    1887  2019-08  아프리카
# 6957   아프리카 기타    2081   593  165    841   1184    4864  2019-08  아프리카
# 6958      국적미상      36     1    0      8     12      57  2019-08  기타대륙
# 6959        교포       0     0    0      0  16560   16560  2019-08    교포
#
#       관광객비율(%)  전체비율(%)
# 0         97.0     50.6
# 1         98.3      8.9
# 2         95.4      3.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6960 entries, 0 to 6959
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국적        6960 non-null   object
#  1   관광        6960 non-null   int64
#  2   상용        6960 non-null   int64
#  3   공용        6960 non-null   int64
#  4   유학/연수     6960 non-null   int64
#  5   기타        6960 non-null   int64
#  6   계         6960 non-null   int64
#  7   기준년월      6960 non-null   object
#  8   대륙        6960 non-null   object
#  9   관광객비율(%)  6960 non-null   float64
#  10  전체비율(%)   6960 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 598.2+ KB

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# 시각화 - 일본
japan = df[df['국적']=='일본']
x = japan['기준년월']
y = japan['관광']

plt.figure(figsize =(15,4))
plt.plot(x,y)
plt.xlabel('기준년월'), plt.ylabel('관광'), plt.title('일본 관광수')
plt.xticks(x.unique()[::12])
plt.show()

# %%
# 시험 나올듯한거 뭐 예를 들어.
# 각 나라별로 가장 많이 관광객이 입국하는 월을 출력하라.
japan['월'] = japan['기준년월'].str[5:7]
month_grouped = japan.groupby(['월'])
month_grouped[['관광']].sum().sort_values(by='관광', ascending=False)
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_15168\2602674620.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   japan['월'] = japan['기준년월'].str[5:7]
#          관광
# 월
# 03  2787014
# 08  2555887
# 05  2157994
# 10  2152971
# 09  2100365
# 11  2091925
# 04  2069622
# 06  2061847
# 07  2058285
# 02  1930212
# 12  1898844
# 01  1755658

# %% [markdown]
# 3월에 제일 많이 갔네요

# %%
monthly_tourists = japan.groupby('월')['관광'].sum()

# 관광객이 가장 많은 월 찾기
max_tourism_month = monthly_tourists.idxmax()
max_tourism_value = monthly_tourists.max()

print(f"관광객이 가장 많이 입국한 달: {max_tourism_month}월, 관광객 수: {max_tourism_value}")
# Out:
# 관광객이 가장 많이 입국한 달: 03월, 관광객 수: 2787014

# %%
# 각 나라별 관광객 수 출력하기
cntry_list = ['중국','일본','대만','미국','홍콩']

for country in cntry_list:
    df_country = df[df['국적']==country]
    x = df_country['기준년월']
    y = df_country['관광']

    plt.figure(figsize =(15,4))
    plt.plot(x,y)
    plt.xlabel('기준년월'), plt.ylabel('관광객 수'), plt.title(f'{country} 국적의 관광객 추이')
    plt.xticks(x.unique()[::12])

plt.show()

# %%
# 년도랑 월 컬럼 생성
df['년도']=df['기준년월'].str[:4]
df['월']=df['기준년월'].str[5:]
df
# Out:
#             국적      관광    상용   공용  유학/연수     기타       계     기준년월    대륙  \
# 0           일본  202825  1750   89    549   3971  209184  2010-01   아시아
# 1           대만   35788    41   17     37    516   36399  2010-01   아시아
# 2           홍콩   13874    55    0     21    595   14545  2010-01   아시아
# 3          마카오     554     0    0      0      0     554  2010-01   아시아
# 4           태국   13374    39   13     53   4335   17814  2010-01   아시아
# ...        ...     ...   ...  ...    ...    ...     ...      ...   ...
# 6955    대양주 기타     519     1    6      9     74     609  2019-08   대양주
# 6956  남아프리카공화국     634     6    1     11   1235    1887  2019-08  아프리카
# 6957   아프리카 기타    2081   593  165    841   1184    4864  2019-08  아프리카
# 6958      국적미상      36     1    0      8     12      57  2019-08  기타대륙
# 6959        교포       0     0    0      0  16560   16560  2019-08    교포
#
#       관광객비율(%)  전체비율(%)    년도   월
# 0         97.0     50.6  2010  01
# 1         98.3      8.9  2010  01
# ...

# %%
# 중국 관광객 필터링

china = df[df['국적']=='중국']
china
# Out:
#       국적      관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17    중국   40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77    중국   60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137   중국   50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197   중국   84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257   중국   89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
# ...   ..     ...    ...  ...    ...    ...     ...      ...  ...       ...
# 6677  중국  410542   3575  362   9959  68812  493250  2019-04  아시아      83.2
# 6737  중국  413949   4034  534  14003  67893  500413  2019-05  아시아      82.7
# 6797  중국  395196   3743  399  14680  60989  475007  2019-06  아시아      83.2
# 6857  중국  439699   3587  356  10847  64643  519132  2019-07  아시아      84.7
# 6917  중국  451570   3625  388  44291  78238  578112  2019-08  아시아      78.1
#
#       전체비율(%)    년도   월
# 17       10.1  2010  01
# ...

# %%
# 피봇 테이블 써서 관광객 수랑 index는 년도로

china_pivot = china.pivot_table(index='년도', values='관광',columns='월')
china_pivot
# Out:
# 월           01        02        03        04        05        06        07  \
# 년도
# 2010   40425.0   60590.0   50330.0   84252.0   89056.0   87080.0  122432.0
# 2011   55070.0   53863.0   72003.0   86397.0   85668.0  108060.0  170524.0
# 2012  106606.0   74895.0  110965.0  166843.0  154841.0  179074.0  258907.0
# 2013  148118.0  169395.0  182850.0  250549.0  196306.0  280319.0  417991.0
# 2014  230706.0  219533.0  313400.0  429419.0  410971.0  429991.0  540683.0
# 2015  327225.0  413096.0  386386.0  536428.0  517154.0  223101.0  172075.0
# 2016  456636.0  424232.0  500018.0  601460.0  614636.0  671493.0  823016.0
# 2017  489256.0  458952.0  263788.0  158784.0  172527.0  181507.0  207099.0
# 2018  236825.0  237075.0  281020.0  283533.0  284317.0  303405.0  332657.0
# 2019  320113.0  324291.0  369165.0  410542.0  413949.0  395196.0  439699.0
#
# 월           08        09        10        11        12
# 년도
# 2010  142180.0   93545.0  107237.0   75686.0   58987.0
# ...

# %%
# 중국 관광객 히트맵

import seaborn as sns
plt.figure(figsize=(16,10))
sns.heatmap(china_pivot, annot=True, fmt='.0f', cmap='rocket_r')
plt.title('중국 관광객 히트맵')
plt.show()

# %%
# cntry 각각 히트맵 그리기

for country in cntry_list:
    country_df = df[df['국적']==country]
    country_pivot = country_df.pivot_table(index='년도', values='관광',columns='월')
    plt.figure(figsize=(16,10))
    sns.heatmap(country_pivot, annot=True, fmt='.0f', cmap='rocket_r')
    plt.title(f'{country} 관광객 히트맵')
plt.show()
